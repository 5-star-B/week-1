# %% [markdown]
# <a href="https://colab.research.google.com/github/5-star-B/week-1/blob/main/mode.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from statistics import mode
path = "/content/drive/MyDrive/statistic/high school data set.csv"

data = pd.read_csv(path)

column_mode = mode(data['دەرەجەی پۆلی ١٢ چەند بوو؟'])

print('Mode of', 'the degree of high school', ':', column_mode)
# Out:
# Mode of the degree of high school : 80-90
